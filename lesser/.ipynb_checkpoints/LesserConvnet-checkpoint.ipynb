# %%
from scipy import io
from scipy.signal import butter, lfilter
import h5py
import random
import numpy as np
import os

# %%
datafolder = "data/sample/alex_long/"

# %%
def butter_bandpass(lowcut, highcut, sampling_rate, order=5):
    nyq_freq = sampling_rate*0.5
    low = lowcut/nyq_freq
    high = highcut/nyq_freq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_high_low_pass(lowcut, highcut, sampling_rate, order=5):
    nyq_freq = sampling_rate*0.5
    lower_bound = lowcut/nyq_freq
    higher_bound = highcut/nyq_freq
    b_high, a_high = butter(order, lower_bound, btype='high')
    b_low, a_low = butter(order, higher_bound, btype='low')
    return b_high, a_high, b_low, a_low

def butter_bandpass_filter(data, lowcut, highcut, sampling_rate, order=5, how_to_filt = 'separately'):
    if how_to_filt == 'separately':
        b_high, a_high, b_low, a_low = butter_high_low_pass(lowcut, highcut, sampling_rate, order=order)
        y = lfilter(b_high, a_high, data)
        y = lfilter(b_low, a_low, y)
    elif how_to_filt == 'simultaneously':
        b, a = butter_bandpass(lowcut, highcut, sampling_rate, order=order)
        y = lfilter(b, a, data)
    return y

def open_eeg_mat(filename, centered=True):
    all_data = io.loadmat(filename)
    eeg_data = all_data['data_cur']
    if centered:
        eeg_data = eeg_data - np.mean(eeg_data,1)[np.newaxis].T
        print('Data were centered: channels are zero-mean')
    states_labels = all_data['states_cur']
    states_codes = list(np.unique(states_labels)[:])
    sampling_rate = all_data['srate']
    chan_names = all_data['chan_names']
    return eeg_data, states_labels, sampling_rate, chan_names, eeg_data.shape[0], eeg_data.shape[1], states_codes

# %%
train_datas = {}
val_datas = {}
test_datas = {}

def to_onehot(label):
    labels_encoding = {1: np.array([1,0,0]), 2: np.array([0,1,0]), 6: np.array([0,0,1])}
    return labels_encoding[label]

for fname in os.listdir(datafolder):
    filename = datafolder + fname
    [eeg_data, states_labels, sampling_rate, chan_names, chan_numb, samp_numb, states_codes] = open_eeg_mat(filename, centered=False)
    sampling_rate = sampling_rate[0,0]
    eeg_data = butter_bandpass_filter(eeg_data, 0.5, 45, sampling_rate, order=5, how_to_filt = 'simultaneously')
    
    states_labels = states_labels[0]
    print(states_labels)
    states_labels = states_labels[2000:]
    eeg_data = eeg_data[:,2000:]
    
    experiment_name = "_".join(fname.split("_")[:-1])
    if fname.endswith("_2val.mat"):
        val_datas[experiment_name] = {"eeg_data": eeg_data.T, "labels": states_labels}
    elif fname.endswith("_1.mat"):
        train_datas[experiment_name] = {"eeg_data": eeg_data.T, "labels": states_labels}
    elif fname.endswith("_2test.mat"):
        test_datas[experiment_name] = {"eeg_data": eeg_data.T, "labels": states_labels}
# Out:
# [1 1 1 ..., 6 6 6]
# [1 1 1 ..., 6 6 6]
# [1 1 1 ..., 6 6 6]
# [1 1 1 ..., 6 6 6]

# %%
from sklearn.preprocessing import StandardScaler

for key in train_datas.keys():
    sc = StandardScaler()
    train_datas[key]["eeg_data"] = sc.fit_transform(train_datas[key]["eeg_data"])
    val_datas[key]["eeg_data"] = sc.transform(val_datas[key]["eeg_data"])
    test_datas[key]["eeg_data"] = sc.transform(test_datas[key]["eeg_data"])

# %%
def generate_slice(val=False):
    if val:
        experiment_data = random.choice(list(val_datas.values()))
    else:
        experiment_data = random.choice(list(train_datas.values()))
    
    X = experiment_data["eeg_data"]
    y = experiment_data["labels"]
    
    while True:
        slice_start = np.random.choice(len(X) - slice_len)
        slice_end = slice_start + slice_len
        slice_x = X[slice_start:slice_end]
        slice_y = y[slice_start:slice_end]
        
        if len(set(slice_y)) == 1:
            return slice_x, to_onehot(slice_y[-1])

# %%
def data_generator(batch_size, val=False):
    while True:
        batch_x = []
        batch_y = []
        
        for i in range(0, batch_size):
            x, y = generate_slice(val=val)
            batch_x.append(x)
            batch_y.append(y)
            
        y = np.array(batch_y)
        x = np.array([i for i in batch_x])
        yield (x, y)

# %%
from keras.layers import Convolution1D, Dense, Dropout, Input, merge, GlobalMaxPooling1D, MaxPooling1D, Flatten, LSTM
from keras.models import Model, load_model
from keras.optimizers import RMSprop

# %%
slice_len = 250

nb_filters = 10
kernel_size = 5

conv1d_act = "relu"

dense1_n = 20
dense1_act = "relu"

dense2_n = 20
dense2_act = "relu"

do = 0.3

path_to_save_model = datafolder.rstrip('/')+'_models/saved_'+'_'+str(slice_len)+'_'+str(nb_filters)+'_'+str(kernel_size)+conv1d_act+'_'+str(dense1_n)+dense1_act+'_'+str(dense2_n)+dense2_act+'_'+str(do)

# %%
path_to_save_model
# Out:
# 'data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3'

# %%
numiter = 5;

# %%
for i in range(numiter):
    
    input_seq = Input(shape=(slice_len, 24))
    convolved = Convolution1D(nb_filters, kernel_size, border_mode="same", activation=conv1d_act)(input_seq)
    pooled = GlobalMaxPooling1D()(convolved)
    dense1 = Dense(dense1_n, activation=dense1_act)(pooled)
    dense1do = Dropout(do)(dense1)
    dense2 = Dense(dense2_n, activation=dense2_act)(dense1do)
    dense2do = Dropout(do)(dense2)
    out = Dense(3, activation='softmax')(dense2do)

    model = Model(input=input_seq, output=out)  

    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["categorical_accuracy"])

    from keras.callbacks import EarlyStopping, ModelCheckpoint

    #nb_epoch = 100000
    earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='auto')
    checkpointer = ModelCheckpoint(path_to_save_model+'_'+str(i), monitor='val_categorical_accuracy', verbose=1,
                                   save_best_only=True, mode='auto', period=1)

    samples_per_epoch = 5000
    nb_epoch = 30

    history = model.fit_generator(data_generator(batch_size=25), samples_per_epoch, nb_epoch, 
                        callbacks=[earlyStopping, checkpointer], verbose=2, nb_val_samples=5000, 
                        validation_data=data_generator(batch_size=25, val=True))
    
    #plt.plot(history.history['val_categorical_accuracy'])
    #plt.savefig(path_to_save_model+'_'str(i)+'.png')
# Out:
# Epoch 1/30
# Epoch 00000: val_categorical_accuracy improved from -inf to 0.40940, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_0
# 15s - loss: 1.0969 - categorical_accuracy: 0.3536 - val_loss: 1.1014 - val_categorical_accuracy: 0.4094
# Epoch 2/30
# Epoch 00001: val_categorical_accuracy did not improve
# 3s - loss: 1.0935 - categorical_accuracy: 0.3758 - val_loss: 1.0948 - val_categorical_accuracy: 0.4090
# Epoch 3/30
# Epoch 00002: val_categorical_accuracy improved from 0.40940 to 0.46920, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_0
# 3s - loss: 1.0835 - categorical_accuracy: 0.4162 - val_loss: 1.0872 - val_categorical_accuracy: 0.4692
# Epoch 4/30
# Epoch 00003: val_categorical_accuracy improved from 0.46920 to 0.52900, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_0
# 3s - loss: 1.0634 - categorical_accuracy: 0.4344 - val_loss: 1.0887 - val_categorical_accuracy: 0.5290
# Epoch 5/30
# Epoch 00004: val_categorical_accuracy improved from 0.52900 to 0.57680, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_0
# 3s - loss: 1.0228 - categorical_accuracy: 0.4830 - val_loss: 1.1331 - val_categorical_accuracy: 0.5768
# Epoch 6/30
# Epoch 00005: val_categorical_accuracy did not improve
# 3s - loss: 0.9890 - categorical_accuracy: 0.4866 - val_loss: 1.2594 - val_categorical_accuracy: 0.5226
# Epoch 7/30
# Epoch 00006: val_categorical_accuracy did not improve
# 3s - loss: 0.9694 - categorical_accuracy: 0.5034 - val_loss: 1.3030 - val_categorical_accuracy: 0.5600
# Epoch 8/30
# Epoch 00007: val_categorical_accuracy did not improve
# 3s - loss: 0.9519 - categorical_accuracy: 0.5104 - val_loss: 1.2971 - val_categorical_accuracy: 0.4894
# Epoch 9/30
# Epoch 00008: val_categorical_accuracy did not improve
# 3s - loss: 0.9541 - categorical_accuracy: 0.5142 - val_loss: 1.3954 - val_categorical_accuracy: 0.5472
# Epoch 10/30
# Epoch 00009: val_categorical_accuracy did not improve
# 3s - loss: 0.9363 - categorical_accuracy: 0.5324 - val_loss: 1.3911 - val_categorical_accuracy: 0.4684
# Epoch 11/30
# Epoch 00010: val_categorical_accuracy did not improve
# 3s - loss: 0.9388 - categorical_accuracy: 0.5324 - val_loss: 1.4078 - val_categorical_accuracy: 0.4936
# Epoch 12/30
# Epoch 00011: val_categorical_accuracy did not improve
# 3s - loss: 0.9340 - categorical_accuracy: 0.5256 - val_loss: 1.4266 - val_categorical_accuracy: 0.4994
# Epoch 13/30
# Epoch 00012: val_categorical_accuracy did not improve
# 3s - loss: 0.9154 - categorical_accuracy: 0.5358 - val_loss: 1.4977 - val_categorical_accuracy: 0.4426
# Epoch 14/30
# Epoch 00013: val_categorical_accuracy did not improve
# 3s - loss: 0.9243 - categorical_accuracy: 0.5440 - val_loss: 1.5525 - val_categorical_accuracy: 0.4870
# Epoch 1/30
# Epoch 00000: val_categorical_accuracy improved from -inf to 0.41460, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 15s - loss: 1.1068 - categorical_accuracy: 0.3404 - val_loss: 1.0938 - val_categorical_accuracy: 0.4146
# Epoch 2/30
# Epoch 00001: val_categorical_accuracy improved from 0.41460 to 0.48120, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 1.0985 - categorical_accuracy: 0.3766 - val_loss: 1.0873 - val_categorical_accuracy: 0.4812
# Epoch 3/30
# Epoch 00002: val_categorical_accuracy improved from 0.48120 to 0.53140, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 1.0929 - categorical_accuracy: 0.3786 - val_loss: 1.0753 - val_categorical_accuracy: 0.5314
# Epoch 4/30
# Epoch 00003: val_categorical_accuracy did not improve
# 3s - loss: 1.0907 - categorical_accuracy: 0.3926 - val_loss: 1.0562 - val_categorical_accuracy: 0.5130
# Epoch 5/30
# Epoch 00004: val_categorical_accuracy improved from 0.53140 to 0.58300, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 1.0616 - categorical_accuracy: 0.4346 - val_loss: 0.9861 - val_categorical_accuracy: 0.5830
# Epoch 6/30
# Epoch 00005: val_categorical_accuracy improved from 0.58300 to 0.61100, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 1.0193 - categorical_accuracy: 0.4710 - val_loss: 0.8960 - val_categorical_accuracy: 0.6110
# Epoch 7/30
# Epoch 00006: val_categorical_accuracy improved from 0.61100 to 0.61300, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.9517 - categorical_accuracy: 0.5012 - val_loss: 0.8545 - val_categorical_accuracy: 0.6130
# Epoch 8/30
# Epoch 00007: val_categorical_accuracy improved from 0.61300 to 0.65320, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.8839 - categorical_accuracy: 0.5560 - val_loss: 0.8445 - val_categorical_accuracy: 0.6532
# Epoch 9/30
# Epoch 00008: val_categorical_accuracy improved from 0.65320 to 0.66780, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.8649 - categorical_accuracy: 0.5614 - val_loss: 0.7910 - val_categorical_accuracy: 0.6678
# Epoch 10/30
# Epoch 00009: val_categorical_accuracy did not improve
# 3s - loss: 0.8355 - categorical_accuracy: 0.5588 - val_loss: 0.7682 - val_categorical_accuracy: 0.6284
# Epoch 11/30
# Epoch 00010: val_categorical_accuracy did not improve
# 3s - loss: 0.7949 - categorical_accuracy: 0.5858 - val_loss: 0.7659 - val_categorical_accuracy: 0.6564
# Epoch 12/30
# Epoch 00011: val_categorical_accuracy improved from 0.66780 to 0.71040, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.7725 - categorical_accuracy: 0.5910 - val_loss: 0.7379 - val_categorical_accuracy: 0.7104
# Epoch 13/30
# Epoch 00012: val_categorical_accuracy did not improve
# 3s - loss: 0.7566 - categorical_accuracy: 0.6058 - val_loss: 0.7527 - val_categorical_accuracy: 0.6962
# Epoch 14/30
# Epoch 00013: val_categorical_accuracy did not improve
# 3s - loss: 0.7382 - categorical_accuracy: 0.6056 - val_loss: 0.7095 - val_categorical_accuracy: 0.6508
# Epoch 15/30
# Epoch 00014: val_categorical_accuracy did not improve
# 3s - loss: 0.7359 - categorical_accuracy: 0.6066 - val_loss: 0.6924 - val_categorical_accuracy: 0.7072
# Epoch 16/30
# Epoch 00015: val_categorical_accuracy did not improve
# 3s - loss: 0.7134 - categorical_accuracy: 0.6132 - val_loss: 0.6820 - val_categorical_accuracy: 0.6662
# Epoch 17/30
# Epoch 00016: val_categorical_accuracy did not improve
# 3s - loss: 0.7148 - categorical_accuracy: 0.6202 - val_loss: 0.6775 - val_categorical_accuracy: 0.6698
# Epoch 18/30
# Epoch 00017: val_categorical_accuracy improved from 0.71040 to 0.73480, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.6868 - categorical_accuracy: 0.6358 - val_loss: 0.6872 - val_categorical_accuracy: 0.7348
# Epoch 19/30
# Epoch 00018: val_categorical_accuracy did not improve
# 3s - loss: 0.6936 - categorical_accuracy: 0.6146 - val_loss: 0.6929 - val_categorical_accuracy: 0.7202
# Epoch 20/30
# Epoch 00019: val_categorical_accuracy did not improve
# 3s - loss: 0.7051 - categorical_accuracy: 0.6238 - val_loss: 0.6441 - val_categorical_accuracy: 0.7312
# Epoch 21/30
# Epoch 00020: val_categorical_accuracy did not improve
# 3s - loss: 0.6883 - categorical_accuracy: 0.6284 - val_loss: 0.6623 - val_categorical_accuracy: 0.7152
# Epoch 22/30
# Epoch 00021: val_categorical_accuracy did not improve
# 3s - loss: 0.6976 - categorical_accuracy: 0.6306 - val_loss: 0.6601 - val_categorical_accuracy: 0.7296
# Epoch 23/30
# Epoch 00022: val_categorical_accuracy improved from 0.73480 to 0.74360, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_1
# 3s - loss: 0.6811 - categorical_accuracy: 0.6334 - val_loss: 0.6542 - val_categorical_accuracy: 0.7436
# Epoch 24/30
# Epoch 00023: val_categorical_accuracy did not improve
# 3s - loss: 0.6769 - categorical_accuracy: 0.6216 - val_loss: 0.6526 - val_categorical_accuracy: 0.7336
# Epoch 25/30
# Epoch 00024: val_categorical_accuracy did not improve
# 3s - loss: 0.6868 - categorical_accuracy: 0.6424 - val_loss: 0.6708 - val_categorical_accuracy: 0.7108
# Epoch 26/30
# Epoch 00025: val_categorical_accuracy did not improve
# 3s - loss: 0.7018 - categorical_accuracy: 0.6140 - val_loss: 0.6397 - val_categorical_accuracy: 0.7274
# Epoch 27/30
# Epoch 00026: val_categorical_accuracy did not improve
# 3s - loss: 0.6701 - categorical_accuracy: 0.6300 - val_loss: 0.6633 - val_categorical_accuracy: 0.7278
# Epoch 28/30
# Epoch 00027: val_categorical_accuracy did not improve
# 3s - loss: 0.6649 - categorical_accuracy: 0.6412 - val_loss: 0.6448 - val_categorical_accuracy: 0.7256
# Epoch 29/30
# Epoch 00028: val_categorical_accuracy did not improve
# 3s - loss: 0.6613 - categorical_accuracy: 0.6466 - val_loss: 0.6653 - val_categorical_accuracy: 0.7276
# Epoch 30/30
# Epoch 00029: val_categorical_accuracy did not improve
# 3s - loss: 0.6808 - categorical_accuracy: 0.6384 - val_loss: 0.6719 - val_categorical_accuracy: 0.7256
# Epoch 1/30
# Epoch 00000: val_categorical_accuracy improved from -inf to 0.33440, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 15s - loss: 1.1002 - categorical_accuracy: 0.3460 - val_loss: 1.0966 - val_categorical_accuracy: 0.3344
# Epoch 2/30
# Epoch 00001: val_categorical_accuracy improved from 0.33440 to 0.37480, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 1.1013 - categorical_accuracy: 0.3502 - val_loss: 1.0973 - val_categorical_accuracy: 0.3748
# Epoch 3/30
# Epoch 00002: val_categorical_accuracy did not improve
# 3s - loss: 1.0956 - categorical_accuracy: 0.3684 - val_loss: 1.0984 - val_categorical_accuracy: 0.3546
# Epoch 4/30
# Epoch 00003: val_categorical_accuracy improved from 0.37480 to 0.39920, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 1.0923 - categorical_accuracy: 0.3952 - val_loss: 1.0989 - val_categorical_accuracy: 0.3992
# Epoch 5/30
# Epoch 00004: val_categorical_accuracy improved from 0.39920 to 0.43660, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 1.0850 - categorical_accuracy: 0.4118 - val_loss: 1.1059 - val_categorical_accuracy: 0.4366
# Epoch 6/30
# Epoch 00005: val_categorical_accuracy improved from 0.43660 to 0.46220, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 1.0484 - categorical_accuracy: 0.4552 - val_loss: 1.0681 - val_categorical_accuracy: 0.4622
# Epoch 7/30
# Epoch 00006: val_categorical_accuracy improved from 0.46220 to 0.47460, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 1.0053 - categorical_accuracy: 0.4834 - val_loss: 1.1149 - val_categorical_accuracy: 0.4746
# Epoch 8/30
# Epoch 00007: val_categorical_accuracy improved from 0.47460 to 0.47520, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 0.9709 - categorical_accuracy: 0.5236 - val_loss: 1.0893 - val_categorical_accuracy: 0.4752
# Epoch 9/30
# Epoch 00008: val_categorical_accuracy did not improve
# 3s - loss: 0.9549 - categorical_accuracy: 0.5342 - val_loss: 1.1201 - val_categorical_accuracy: 0.4514
# Epoch 10/30
# Epoch 00009: val_categorical_accuracy improved from 0.47520 to 0.47960, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 0.9220 - categorical_accuracy: 0.5634 - val_loss: 1.1511 - val_categorical_accuracy: 0.4796
# Epoch 11/30
# Epoch 00010: val_categorical_accuracy did not improve
# 3s - loss: 0.9018 - categorical_accuracy: 0.5778 - val_loss: 1.1467 - val_categorical_accuracy: 0.4584
# Epoch 12/30
# Epoch 00011: val_categorical_accuracy improved from 0.47960 to 0.48320, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 0.8971 - categorical_accuracy: 0.5826 - val_loss: 1.1377 - val_categorical_accuracy: 0.4832
# Epoch 13/30
# Epoch 00012: val_categorical_accuracy did not improve
# 3s - loss: 0.8699 - categorical_accuracy: 0.6036 - val_loss: 1.2082 - val_categorical_accuracy: 0.4674
# Epoch 14/30
# Epoch 00013: val_categorical_accuracy improved from 0.48320 to 0.48720, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_2
# 3s - loss: 0.8852 - categorical_accuracy: 0.5934 - val_loss: 1.2043 - val_categorical_accuracy: 0.4872
# Epoch 15/30
# Epoch 00014: val_categorical_accuracy did not improve
# 3s - loss: 0.8649 - categorical_accuracy: 0.5992 - val_loss: 1.2121 - val_categorical_accuracy: 0.4540
# Epoch 16/30
# Epoch 00015: val_categorical_accuracy did not improve
# 3s - loss: 0.8488 - categorical_accuracy: 0.6138 - val_loss: 1.2043 - val_categorical_accuracy: 0.4632
# Epoch 17/30
# Epoch 00016: val_categorical_accuracy did not improve
# 3s - loss: 0.8592 - categorical_accuracy: 0.6022 - val_loss: 1.2897 - val_categorical_accuracy: 0.4630
# Epoch 1/30
# Epoch 00000: val_categorical_accuracy improved from -inf to 0.29660, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 15s - loss: 1.1035 - categorical_accuracy: 0.3382 - val_loss: 1.1002 - val_categorical_accuracy: 0.2966
# Epoch 2/30
# Epoch 00001: val_categorical_accuracy improved from 0.29660 to 0.34660, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 3s - loss: 1.0955 - categorical_accuracy: 0.3608 - val_loss: 1.0979 - val_categorical_accuracy: 0.3466
# Epoch 3/30
# Epoch 00002: val_categorical_accuracy improved from 0.34660 to 0.41820, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 3s - loss: 1.0803 - categorical_accuracy: 0.3838 - val_loss: 1.0948 - val_categorical_accuracy: 0.4182
# Epoch 4/30
# Epoch 00003: val_categorical_accuracy did not improve
# 3s - loss: 1.0544 - categorical_accuracy: 0.4440 - val_loss: 1.1022 - val_categorical_accuracy: 0.4128
# Epoch 5/30
# Epoch 00004: val_categorical_accuracy improved from 0.41820 to 0.44920, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 3s - loss: 1.0117 - categorical_accuracy: 0.5102 - val_loss: 1.0757 - val_categorical_accuracy: 0.4492
# Epoch 6/30
# Epoch 00005: val_categorical_accuracy improved from 0.44920 to 0.48000, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 3s - loss: 0.9828 - categorical_accuracy: 0.5372 - val_loss: 1.0487 - val_categorical_accuracy: 0.4800
# Epoch 7/30
# Epoch 00006: val_categorical_accuracy did not improve
# 3s - loss: 0.9534 - categorical_accuracy: 0.5450 - val_loss: 1.0836 - val_categorical_accuracy: 0.4634
# Epoch 8/30
# Epoch 00007: val_categorical_accuracy did not improve
# 3s - loss: 0.9184 - categorical_accuracy: 0.5732 - val_loss: 1.1390 - val_categorical_accuracy: 0.4582
# Epoch 9/30
# Epoch 00008: val_categorical_accuracy improved from 0.48000 to 0.49560, saving model to data/sample/alex_long_models/saved__250_1_2relu_20relu_20relu_0.3_3
# 3s - loss: 0.8994 - categorical_accuracy: 0.5834 - val_loss: 1.1214 - val_categorical_accuracy: 0.4956
# Epoch 10/30
# Epoch 00009: val_categorical_accuracy did not improve
# 3s - loss: 0.8909 - categorical_accuracy: 0.6046 - val_loss: 1.1899 - val_categorical_accuracy: 0.4544
# Epoch 11/30
# Epoch 00010: val_categorical_accuracy did not improve
# 3s - loss: 0.8805 - categorical_accuracy: 0.6018 - val_loss: 1.2407 - val_categorical_accuracy: 0.4722
# Epoch 12/30
# Epoch 00011: val_categorical_accuracy did not improve
# 3s - loss: 0.8901 - categorical_accuracy: 0.5948 - val_loss: 1.2620 - val_categorical_accuracy: 0.4552
# Epoch 13/30
# Epoch 00012: val_categorical_accuracy did not improve
# 3s - loss: 0.8722 - categorical_accuracy: 0.6088 - val_loss: 1.2924 - val_categorical_accuracy: 0.4752
# Epoch 14/30
# Epoch 00013: val_categorical_accuracy did not improve
# 3s - loss: 0.8722 - categorical_accuracy: 0.6144 - val_loss: 1.2634 - val_categorical_accuracy: 0.4686
# Epoch 15/30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-52282dec1753> in <module>()
#      26     history = model.fit_generator(data_generator(batch_size=25), samples_per_epoch, nb_epoch,
#      27                         callbacks=[earlyStopping, checkpointer], verbose=2, nb_val_samples=5000,
# ---> 28                         validation_data=data_generator(batch_size=25, val=True))
#      29
#      30     #plt.plot(history.history['val_categorical_accuracy'])
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit_generator(self, generator, samples_per_epoch, nb_epoch, verbose, callbacks, validation_data, nb_val_samples, class_weight, max_q_size, nb_worker, pickle_safe, initial_epoch)
#    1506                     outs = self.train_on_batch(x, y,
#    1507                                                sample_weight=sample_weight,
# -> 1508                                                class_weight=class_weight)
#    1509                 except:
#    1510                     _stop.set()
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1265             ins = x + y + sample_weights
#    1266         self._make_train_function()
# -> 1267         outputs = self.train_function(ins)
#    1268         if len(outputs) == 1:
#    1269             return outputs[0]
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    1599                 value = (indices, sparse_coo.data, sparse_coo.shape)
#    1600             feed_dict[tensor] = value
# -> 1601         session = get_session()
#    1602         updated = session.run(self.outputs + [self.updates_op],
#    1603                               feed_dict=feed_dict)
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in get_session()
#     117         session = _SESSION
#     118     if not _MANUAL_VAR_INIT:
# --> 119         _initialize_variables()
#     120     return session
#     121
#
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in _initialize_variables()
#     263     uninitialized_variables = []
#     264     for v in variables:
# --> 265         if not hasattr(v, '_keras_initialized') or not v._keras_initialized:
#     266             uninitialized_variables.append(v)
#     267             v._keras_initialized = True
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(history.history.keys())
# Out:
# ['val_categorical_accuracy', 'loss', 'categorical_accuracy', 'val_loss']

# %%
plt.plot(history.history['val_categorical_accuracy'])

# %%
plt.savefig(path_to_save_model+'.png')

# %%
fname = datafolder.split('/', 3 )[2]

# %%
res = np.zeros([2,numiter]);

for j in range(numiter):
    model = load_model(path_to_save_model+'_'+str(j))

    eeg_data = test_datas[fname]['eeg_data'].T
    idxs = np.arange(0,eeg_data.shape[1],slice_len)
    num_chunks = idxs.shape[0]

    chunks = np.zeros([num_chunks-1,24,slice_len])
    preds = np.zeros([num_chunks-1,3])

    for i in range(num_chunks-1):
        #print(idxs[i])
        chunk = eeg_data[:,idxs[i]:(idxs[i]+slice_len)].T
        chunks[i,:,:] = chunk.T
        preds[i] = model.predict(chunk[None,:,:,])

    a = np.argmax(preds,axis=1)

    a_bin = np.zeros([3,a.shape[0]])

    a_bin[0,:] = (a == 0)
    a_bin[1,:] = (a == 1)
    a_bin[2,:] = (a == 2)

    true_labels = test_datas[fname]['labels']
    true_labels = true_labels[::slice_len]
    true_labels = true_labels[0:-1]

    true_labels_bin = np.zeros([3,true_labels.shape[0]])

    true_labels_bin[0,:] = (true_labels == 1)
    true_labels_bin[1,:] = (true_labels == 2)
    true_labels_bin[2,:] = (true_labels == 6)

    from sklearn.metrics import roc_auc_score

    score1 = roc_auc_score(true_labels_bin,a_bin)
    #print(score1)

    predsT = preds.T;
    score2 = roc_auc_score(true_labels_bin,predsT)
    print(score1,score2)

    res[0,j] = score1;
    res[1,j] = score2;
# Out:
# (0.78076923076923077, 0.84326923076923077)
# (0.83269230769230773, 0.87692307692307692)
# (0.78365384615384615, 0.83269230769230773)
# (0.77211538461538465, 0.83365384615384619)
# (0.72307692307692306, 0.77692307692307694)

# %%
res_av = np.mean(res,axis = 1)
print(res_av)
# Out:
# [ 0.77846154  0.83269231]

# %%
#filename = 'data/ksenia_long_2test'
#filename = 'data/ksenia_long_1'
#[eeg_data, states_labels, sampling_rate, chan_names, chan_numb, samp_numb, states_codes] = open_eeg_mat(filename, centered=False)
#sampling_rate = sampling_rate[0,0]
#eeg_data = butter_bandpass_filter(eeg_data, 0.5, 45, sampling_rate, order=5, how_to_filt = 'simultaneously')

#states_labels = states_labels[0]
#print(states_labels)
#states_labels = states_labels[2000:-2000]
#eeg_data = eeg_data[:,2000:-2000]

# %%
eeg_data = test_datas['ksenia_long']['eeg_data'].T
idxs = np.arange(0,eeg_data.shape[1],slice_len)
num_chunks = idxs.shape[0]
num_chunks
# Out:
# 261

# %%
chunks = np.zeros([num_chunks-1,24,slice_len])
preds = np.zeros([num_chunks-1,3])

for i in range(num_chunks-1):
    #print(idxs[i])
    chunk = eeg_data[:,idxs[i]:(idxs[i]+slice_len)].T
    chunks[i,:,:] = chunk.T
    preds[i] = model.predict(chunk[None,:,:,])

# %%
a = np.argmax(preds,axis=1)

a_bin = np.zeros([3,a.shape[0]])

a_bin[0,:] = (a == 0)
a_bin[1,:] = (a == 1)
a_bin[2,:] = (a == 2)
              
plt.imshow(a_bin, extent=[0, 1, 0, 1])

# %%
print(preds.shape)
print(a.shape)

true_labels = test_datas['ksenia_long']['labels']
true_labels = true_labels[::slice_len]
true_labels = true_labels[0:-1]
print(true_labels.shape)

true_labels_bin = np.zeros([3,true_labels.shape[0]])
print(true_labels_bin.shape)

true_labels_bin[0,:] = (true_labels == 1)
true_labels_bin[1,:] = (true_labels == 2)
true_labels_bin[2,:] = (true_labels == 6)
# Out:
# (260, 3)
# (260,)
# (260,)
# (3, 260)

# %%
plt.imshow(true_labels_bin, extent=[0, 1, 0, 1])

# %%
from sklearn.metrics import roc_auc_score

score1 = roc_auc_score(true_labels_bin,a_bin)
print(score1)

predsT = preds.T;
score2 = roc_auc_score(true_labels_bin,predsT)
print(score2)
# Out:
# 0.723076923077
# 0.771153846154

# %%
print(true_labels_bin.shape)
print(a_bin.shape)
# Out:
# (3, 260)
# (3, 260)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-395f3a33b313> in <module>()
# ----> 1 score1 = roc_auc_score(true_labels_bin,a_bin)
#       2 print(score1)
#       3
#       4 predsT = preds.T;
#       5 score2 = roc_auc_score(true_labels_bin,predsT)
#
# NameError: name 'roc_auc_score' is not defined

# %%
plt.imshow(preds, extent=[0, 1, 0, 1])

# %%
model.layers

from matplotlib import pyplot as plt

from vis.utils import utils
from vis.utils.vggnet import VGG16
from vis.visualization import visualize_class_activation


# Build the VGG16 network with ImageNet weights
#model = VGG16(weights='imagenet', include_top=True)
#print('Model loaded.')

# The name of the layer we want to visualize
# (see model definition in vggnet.py)
layer_name = 'dense_2'
layer_idx = [idx for idx, layer in enumerate(model.layers) if layer.name == layer_name][0]

model.layers[3]

idx = 2;
img = visualize_class_activation(model, layer_idx, filter_indices=idx, max_iter=500)

img.shape

plt.imshow(img, extent=[0, 1, 0, 1])

img = utils.draw_text(img, str(idx))

idx_list = [1]*20
idx_list


# Generate three different images of the same output index.
vis_images = []
idx_list = [1]*3
for idx in idx_list: #[0, 0, 0]:
    img = visualize_class_activation(model, layer_idx, filter_indices=idx, max_iter=500)
    #img = utils.draw_text(img, str(idx))
    vis_images.append(img)

plt.imshow(vis_images[0], extent=[0, 1, 0, 1])
# Out:
# [<keras.engine.topology.InputLayer at 0x7f2a2f7b00>,
#  <keras.layers.convolutional.Conv1D at 0x7f273aa160>,
#  <keras.layers.pooling.GlobalMaxPooling1D at 0x7f275cd550>,
#  <keras.layers.core.Dense at 0x7f22e73080>,
#  <keras.layers.core.Dropout at 0x7f27f8eb38>,
#  <keras.layers.core.Dense at 0x7f2a4434a8>,
#  <keras.layers.core.Dropout at 0x7f2a351be0>,
#  <keras.layers.core.Dense at 0x7f2a351630>]
