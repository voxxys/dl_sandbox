# %%
from scipy import io
from scipy.signal import butter, lfilter
import h5py
import random
import numpy as np
import os

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ecog_matfile = io.loadmat('test_ecog_data.mat')
raw_data = ecog_matfile['raw_data']
raw_acc = ecog_matfile['raw_acc']
mv_acc = ecog_matfile['mv_acc']

# %%
chan_names = ecog_matfile['chan_names']

# %%
chan_names = chan_names[0]
chan_names = chan_names.tolist()
for i in range(len(chan_names)):
  chan_names[i] = chan_names[i][0]

# %%
chan_names
# Out:
# ['P3_1_d',
#  'P3_2_d',
#  'F3_1_d',
#  'F3_2_d',
#  'C3_1_d',
#  'C3_2_d',
#  'C3_3_d',
#  'C3_4_d',
#  'T5_1_d',
#  'T5_2_d',
#  'T5_3_d',
#  'T5_4_d']

# %%
raw_data.shape
# Out:
# (12, 136001)

# %%
mv_acc.shape
# Out:
# (1, 136001)

# %%
len_raw_data = raw_data.shape[1]

# %%
raw_data_train = raw_data[4:8,0:(len_raw_data//3)]
raw_data_val = raw_data[4:8,(len_raw_data//3):(len_raw_data//2)]
raw_data_test = raw_data[4:8,(len_raw_data//2):]

mv_acc_train = mv_acc[:,0:(len_raw_data//3)]
mv_acc_val = mv_acc[:,(len_raw_data//3):(len_raw_data//2)]
mv_acc_test = mv_acc[:,(len_raw_data//2):]

# %%
print(raw_data_train.shape)
print(raw_data_val.shape)
print(raw_data_test.shape)
print(mv_acc_train.shape)
print(mv_acc_val.shape)
print(mv_acc_test.shape)
# Out:
# (4, 45333)
# (4, 22667)
# (4, 68001)
# (1, 45333)
# (1, 22667)
# (1, 68001)

# %%
mv_acc[0,::10].shape
# Out:
# (13601,)

# %%
plt.plot(mv_acc[0,::10])

# %%
slice_len = 1000

# %%
def generate_slice(slice_len, val=False):
    if val:
        X = raw_data_val
        y = mv_acc_val
    else:
        X = raw_data_train
        y = mv_acc_train
    
    len_X = X.shape[1]
    
    while True:
        slice_start = np.random.choice(len_X - slice_len)
        slice_end = slice_start + slice_len
        slice_x = X[:,slice_start:slice_end].T
        slice_y = y[0,slice_end]

        return slice_x, slice_y

# %%
tX, ty = generate_slice(slice_len)

# %%
tX.shape
# Out:
# (1000, 4)

# %%
ty
# Out:
# 0.40653792717392895

# %%
def data_generator(batch_size, slice_len, val=False):
    while True:
        batch_x = []
        batch_y = []
        
        for i in range(0, batch_size):
            x, y = generate_slice(slice_len, val=val)
            batch_x.append(x)
            batch_y.append(y)
            
        y = np.array(batch_y)
        x = np.array([i for i in batch_x])
        yield (x, y)

# %%
slice_len = 1000

nb_filters = 10
kernel_size = 20

conv1d_act = "relu"

dense1_n = 20
dense1_act = "tanh"

do = 0

path_to_save_model = 'testmodel'

# %%
from keras.layers import Convolution1D, Dense, Dropout, Input, merge, GlobalMaxPooling1D, MaxPooling1D, Flatten, LSTM
from keras.models import Model, load_model
from keras.optimizers import RMSprop

# %%
input_seq = Input(shape=(slice_len, 4))
convolved = Convolution1D(nb_filters, kernel_size, border_mode="same", activation=conv1d_act)(input_seq)
pooled = GlobalMaxPooling1D()(convolved)
dense1 = Dense(dense1_n, activation=dense1_act)(pooled)
dense1do = Dropout(do)(dense1)
out = Dense(1, activation='linear')(dense1do)

model = Model(input=input_seq, output=out)

model.compile(loss="mse", optimizer="RMSprop", metrics=["mse"])

from keras.callbacks import EarlyStopping, ModelCheckpoint

#nb_epoch = 100000
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='auto')
checkpointer = ModelCheckpoint(path_to_save_model+'_'+str(i), monitor='val_loss', verbose=1,
                               save_best_only=True, mode='auto', period=1)

samples_per_epoch = 3000
nb_epoch = 30
# Out:
# C:\Users\voxxys\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(10, 20, activation="relu", padding="same")`
#
# C:\Users\voxxys\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   # Remove the CWD from sys.path while we load stuff.

# %%
history = model.fit_generator(data_generator(slice_len = 1000, batch_size=25), samples_per_epoch, nb_epoch, 
                    callbacks=[earlyStopping, checkpointer], verbose=1, nb_val_samples=1000, 
                    validation_data=data_generator(slice_len = 1000, batch_size=25, val=True))
# Out:
# C:\Users\voxxys\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<generator..., 3000, 30, callbacks=[<keras.ca..., verbose=1, validation_data=<generator..., validation_steps=1000)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/30
#   28/3000 [..............................] - ETA: 195s - loss: 0.2573 - mean_squared_error: 0.2573
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.784555). Check your callbacks.
#   % delta_t_median)
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.693991). Check your callbacks.
#   % delta_t_median)
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.603428). Check your callbacks.
#   % delta_t_median)
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.302215). Check your callbacks.
#   % delta_t_median)
# 2995/3000 [============================>.] - ETA: 0s - loss: 0.2552 - mean_squared_error: 0.2552Epoch 00000: val_loss improved from inf to 0.36101, saving model to testmodel_11
# 3000/3000 [==============================] - 29s - loss: 0.2552 - mean_squared_error: 0.2552 - val_loss: 0.3610 - val_mean_squared_error: 0.3610
# Epoch 2/30
# 2993/3000 [============================>.] - ETA: 0s - loss: 0.2550 - mean_squared_error: 0.2550Epoch 00001: val_loss improved from 0.36101 to 0.35585, saving model to testmodel_11
# 3000/3000 [==============================] - 27s - loss: 0.2550 - mean_squared_error: 0.2550 - val_loss: 0.3558 - val_mean_squared_error: 0.3558
# Epoch 3/30
# 2996/3000 [============================>.] - ETA: 0s - loss: 0.2549 - mean_squared_error: 0.2549 ETA: 0s - loss: 0.2550 - mean_sEpoch 00002: val_loss improved from 0.35585 to 0.35322, saving model to testmodel_11
# 3000/3000 [==============================] - 27s - loss: 0.2549 - mean_squared_error: 0.2549 - val_loss: 0.3532 - val_mean_squared_error: 0.3532
# Epoch 4/30
# 2997/3000 [============================>.] - ETA: 0s - loss: 0.2538 - mean_squared_error: 0.2538Epoch 00003: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2538 - mean_squared_error: 0.2538 - val_loss: 0.3559 - val_mean_squared_error: 0.3559
# Epoch 5/30
# 2995/3000 [============================>.] - ETA: 0s - loss: 0.2549 - mean_squared_error: 0.2549Epoch 00004: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2549 - mean_squared_error: 0.2549 - val_loss: 0.3552 - val_mean_squared_error: 0.3552
# Epoch 6/30
# 2992/3000 [============================>.] - ETA: 0s - loss: 0.2558 - mean_squared_error: 0.2558Epoch 00005: val_loss did not improve
# 3000/3000 [==============================] - 29s - loss: 0.2559 - mean_squared_error: 0.2559 - val_loss: 0.3572 - val_mean_squared_error: 0.3572
# Epoch 7/30
#   25/3000 [..............................] - ETA: 45s - loss: 0.2444 - mean_squared_error: 0.2444
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.154109). Check your callbacks.
#   % delta_t_median)
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.103573). Check your callbacks.
#   % delta_t_median)
# 2992/3000 [============================>.] - ETA: 0s - loss: 0.2562 - mean_squared_error: 0.2562Epoch 00006: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2562 - mean_squared_error: 0.2562 - val_loss: 0.3581 - val_mean_squared_error: 0.3581
# Epoch 8/30
# 2997/3000 [============================>.] - ETA: 0s - loss: 0.2553 - mean_squared_error: 0.2553Epoch 00007: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2553 - mean_squared_error: 0.2553 - val_loss: 0.3571 - val_mean_squared_error: 0.3571
# Epoch 9/30
# 2997/3000 [============================>.] - ETA: 0s - loss: 0.2555 - mean_squared_error: 0.2555Epoch 00008: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2555 - mean_squared_error: 0.2555 - val_loss: 0.3571 - val_mean_squared_error: 0.3571
# Epoch 10/30
# 2993/3000 [============================>.] - ETA: 0s - loss: 0.2547 - mean_squared_error: 0.2547Epoch 00009: val_loss did not improve
# 3000/3000 [==============================] - 27s - loss: 0.2547 - mean_squared_error: 0.2547 - val_loss: 0.3584 - val_mean_squared_error: 0.3584
# Epoch 11/30
# 2995/3000 [============================>.] - ETA: 0s - loss: 0.2567 - mean_squared_error: 0.2567Epoch 00010: val_loss did not improve
# 3000/3000 [==============================] - 30s - loss: 0.2568 - mean_squared_error: 0.2568 - val_loss: 0.3561 - val_mean_squared_error: 0.3561
# Epoch 12/30
# 2993/3000 [============================>.] - ETA: 0s - loss: 0.2566 - mean_squared_error: 0.2566Epoch 00011: val_loss did not improve
# 3000/3000 [==============================] - 29s - loss: 0.2566 - mean_squared_error: 0.2566 - val_loss: 0.3540 - val_mean_squared_error: 0.3540
# Epoch 13/30
#   26/3000 [..............................] - ETA: 81s - loss: 0.2553 - mean_squared_error: 0.2553
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.540382). Check your callbacks.
#   % delta_t_median)
# C:\Users\voxxys\Anaconda3\lib\site-packages\keras\callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.270691). Check your callbacks.
#   % delta_t_median)
# 2996/3000 [============================>.] - ETA: 0s - loss: 0.2558 - mean_squared_error: 0.2558Epoch 00012: val_loss did not improve
# 3000/3000 [==============================] - 28s - loss: 0.2559 - mean_squared_error: 0.2559 - val_loss: 0.3573 - val_mean_squared_error: 0.3573
# Epoch 14/30
# 1063/3000 [=========>....................] - ETA: 12s - loss: 0.2537 - mean_squared_error: 0.2537

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(history.history.keys())

plt.plot(history.history['val_loss'])

# %%
tx, ty = generate_slice(slice_len = 1000, val=val)

# %%
a = np.ones((3,4,5))
b = np.ones((3,4,5))
c = np.concatenate((a[...,np.newaxis],b[...,np.newaxis]),axis=3)

txs = np.concatenate((tx[:,:,np.newaxis],tx[:,:,np.newaxis]),axis = 2)
txs.shape

# %%
loss, accuracy = model.evaluate(tx, ty)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-5f2d2f3a6628> in <module>()
# ----> 1 loss, accuracy = model.evaluate(X, y)
#
# NameError: name 'X' is not defined

# %%
idxs = np.arange(0,raw_data_test.shape[1],10)
num_chunks = idxs.shape[0]

chunks = np.zeros([num_chunks-1,24,slice_len])
preds = np.zeros([num_chunks-1,3])

for i in range(num_chunks-1):
    #print(idxs[i])
    chunk = eeg_data[:,idxs[i]:(idxs[i]+slice_len)].T
    chunks[i,:,:] = chunk.T
    preds[i] = model.predict(chunk[None,:,:,])
