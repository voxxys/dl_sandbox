# %%
from slacker import Slacker

slack = Slacker("xoxp-28316847441-28626652993-217839551091-e341c87094d7d95469c969e02cc35e0e")

#attachments = [{"title": "test", "image_url": "D:/file.png"}]

def send_slack_message(message_text):
    slack.chat.post_message("#bot_slacker", message_text, "bot:slacker")
    
def send_slack_picture(picurl):
    slack.files.upload(picurl, channels="#bot_slacker")
