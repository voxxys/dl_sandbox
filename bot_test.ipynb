# %%
from bot_slackclient import send_slack_message

# %%
send_slack_message("test")

# %%
from slackclient import SlackClient

slack_token = "xoxp-28316847441-28626652993-218947199479-1324bbaaeb5bddfa18fc6bee251ce2b4"
sc = SlackClient(slack_token)

# %%
sc.api_call("chat.postMessage", channel="#bot_slackclient", text = "test2")
# Out:
# {'channel': 'G6DUWJ6SZ',
#  'message': {'bot_id': 'B6DNTS6HZ',
#   'subtype': 'bot_message',
#   'text': 'test2',
#   'ts': '1501073039.056770',
#   'type': 'message',
#   'username': 'Slack API Tester'},
#  'ok': True,
#  'ts': '1501073039.056770'}
